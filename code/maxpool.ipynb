# %%
import torch
import torch.nn as nn
import numpy as np
import cv2
import matplotlib.pyplot as plt

path = '../data/CA_DSA/LCA/enhance/000.bmp'
img = cv2.imread(path, 0)

# %%
img.shape
# Out:
# (512, 512)

# %%
img
# Out:
# array([[ 2,  3,  3, ...,  2,  1,  1],
#        [ 3,  4,  3, ...,  2,  2,  1],
#        [ 4,  5,  5, ...,  2,  2,  2],
#        ...,
#        [ 5,  5,  6, ..., 18, 11,  8],
#        [ 3,  4,  5, ..., 13,  6,  4],
#        [ 4,  4,  4, ...,  8,  4,  3]], dtype=uint8)

# %%
plt.imshow(img)
plt.show()

# %%
img = torch.from_numpy(img).unsqueeze(0).unsqueeze(0)

# %%
img
# Out:
# tensor([[[[ 2,  3,  3,  ...,  2,  1,  1],
#           [ 3,  4,  3,  ...,  2,  2,  1],
#           [ 4,  5,  5,  ...,  2,  2,  2],
#           ...,
#           [ 5,  5,  6,  ..., 18, 11,  8],
#           [ 3,  4,  5,  ..., 13,  6,  4],
#           [ 4,  4,  4,  ...,  8,  4,  3]]]], dtype=torch.uint8)

# %%
img1 = nn.MaxPool2d(2)(img/255.0)

# %%
plt.imshow(img1[0][0])
plt.show()

# %%
img2 = nn.MaxPool2d(2)(img1)

# %%
plt.imshow(img2[0][0])
plt.show()

# %%
img3 = nn.MaxPool2d(2)(img2)

# %%
plt.imshow(img3[0][0])
plt.show()
